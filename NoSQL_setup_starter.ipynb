# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
db.establishments.find_one()
# Out:
# {'_id': ObjectId('663d0ad74e28bb22b210bec0'),
#  'FHRSID': 254719,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT15 6DY',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2022-03-24T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#  'RightToReply': '',
#  'Distance': 4587.347174863443,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
list(establishments.find({"BusinessName":"Penang Flavours"}))
# Out:
# [{'_id': ObjectId('663d0b285e1d66c2a84805ab'),
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'PostCode': 'SE18 7DY',
#   'Phone': '',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#   'RightToReply': '',
#   'Distance': 4623.972328074718,
#   'NewRatingPending': True}]

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}

fields = {'BusinessTypeID': 1, 'BusinessType': 1}

list(establishments.find(query, fields))
# Out:
# [{'_id': ObjectId('663d0ad74e28bb22b210bec0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bec3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bec5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bec6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bec7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bec8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bec9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210beca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210becf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bed2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bed3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bed4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bede'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bee1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bee5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bef0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bef2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bef4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bef5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bef8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bef9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210befe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210beff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf01'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf02'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf03'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf04'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf0a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf0b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf0e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf12'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf13'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf14'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf17'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf25'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf26'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf2d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf2e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf2f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf32'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf34'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf35'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf3a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf42'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf43'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf46'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf4a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf4b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf4c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf4e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf4f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf55'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf5c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf5d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf61'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf65'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf6b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf6d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf6f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf70'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf71'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf7b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf7c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf81'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf84'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf89'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf8b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf8c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf91'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf97'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf99'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bf9f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfaf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfb0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfbc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfbf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfc0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfc2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfc5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfd2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfd3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfd8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfde'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfe0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfe2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfe9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bfee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bff5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bffa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bffb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bffc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210bffe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c003'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c006'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c008'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c009'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c00a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c00d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c00e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c00f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c012'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c013'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c014'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c015'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c017'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c01e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c01f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c028'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c02a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c02e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c02f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c032'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c039'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c03b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c03c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c03d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c03e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c041'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c045'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c049'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c04a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c04b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c059'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c05a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c05c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c061'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c062'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c069'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c06b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c06e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c06f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c077'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c079'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c081'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c086'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c088'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c08a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c08d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c090'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c094'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c09a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0a5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0b1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0bb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0d9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0e3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0e4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0ea'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0ed'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c0fb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c10f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c127'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c12b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c137'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c139'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c13b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c13d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c14c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c158'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c159'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c15e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c162'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c165'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c167'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c16d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c16e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c173'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c176'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c177'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c17c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c186'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c187'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c18a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c197'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c19c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c19d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1a2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1a7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1b2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1b6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1ba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1bb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1ca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1d0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1d3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1d7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1d8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1db'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1dc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1f3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1fb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c1ff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c200'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c203'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c205'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c208'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c20a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c20b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c20c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c20d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c214'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c216'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c217'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c21c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c21e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c21f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c220'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c225'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c227'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c230'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c231'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c233'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c237'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c238'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c23b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c23c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c240'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c244'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c245'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c247'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c249'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c24d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c24e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c250'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c254'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c256'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c25a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c25b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c260'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c263'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c265'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c26d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c26e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c270'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c278'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c279'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c27a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c280'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c282'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c284'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c286'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c28c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c28d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c28f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c290'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c291'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c292'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c295'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c29a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c29c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c29d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c29f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2ac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2ad'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2b0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2b1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2b3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2b9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2ba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2bb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2bd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2bf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2c1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2c2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2c8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2cb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2cd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2d3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2dd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2e0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2f9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c2fb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c302'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c303'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c307'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c30b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c31f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c327'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c32a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c32b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c32c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c32f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c339'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c33c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c33d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c33e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c33f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c340'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c341'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c344'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c345'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c346'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c347'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c348'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c34e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c358'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c35b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c35f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c360'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c361'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c362'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c363'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c364'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c366'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c367'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c369'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c36c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c36e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c372'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c374'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c37c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c37d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c37e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c37f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c380'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c381'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c386'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c387'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c392'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c393'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c395'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c396'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c398'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c39a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3a3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3a7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3a9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3ae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3b0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3b5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3b7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3b8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3bb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3c3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3c9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3cf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3d4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3d7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3d9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3dd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3e0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3e3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3eb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3ef'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3f2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3f3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3f6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c3fa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c400'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c403'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c404'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c407'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c40e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c411'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c413'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c417'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c41a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c41b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c41c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c41d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c41e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c41f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c421'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c422'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c424'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c425'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c428'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c429'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c42a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c42b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c42d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c430'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c431'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c432'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c433'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c435'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c436'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c437'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c439'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c43a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c43d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c43f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c447'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c449'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c44a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c44b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c44c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c44e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c456'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c457'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c45a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c45c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c45e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c463'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c465'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c46c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c46e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c47b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c485'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c48d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c492'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c495'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c497'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c49a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad74e28bb22b210c4a2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb01'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb03'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb04'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb09'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb0d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb1b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb1d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb21'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb28'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb2d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb2e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb33'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb41'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb44'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb48'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb54'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb5a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb5b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb65'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb68'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb7a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb7f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb80'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb81'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb83'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb88'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb8a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb95'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb9b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cb9f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cba5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbb4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbc7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbcd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbd3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbd8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbda'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbe2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbe3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbeb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbf0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbf1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cbfe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc00'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc04'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc08'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc0a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc0d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc14'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc25'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc35'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc3f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc40'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc42'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc46'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc47'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc4a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc4c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc4f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc56'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc57'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc61'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc63'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc64'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc66'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc67'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc6b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc6d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc71'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc72'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc74'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc75'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc76'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc78'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc79'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc7b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc7d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc7e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc80'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc83'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc89'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc8a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc99'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc9a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc9c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cc9f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cca4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cca6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cca9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccaa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccab'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccad'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccb3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccb5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccb7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccb8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccc4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccc7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccc8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccc9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cccb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cccf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccd2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccd3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccd4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccd5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccd6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccd8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccdc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccdf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cce1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cce4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cce6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cce7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccea'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cced'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccf0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccf7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccf9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210ccfd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd00'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd01'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd02'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd04'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd06'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd08'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd0b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd0e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd10'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd11'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd14'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd15'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd16'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd17'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd1b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('663d0ad84e28bb22b210cd1c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  ...]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
update_filter = {'BusinessName':'Penang Flavours'}

update_value = {'$set': {'BusinessTypeID': '1'}}

establishments.update_one(update_filter, update_value)

# %%
# Confirm that the new restaurant was updated
list(establishments.find({"BusinessName":"Penang Flavours"}))
# Out:
# [{'_id': ObjectId('663d0b285e1d66c2a84805ab'),
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '1',
#   'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'PostCode': 'SE18 7DY',
#   'Phone': '',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#   'RightToReply': '',
#   'Distance': 4623.972328074718,
#   'NewRatingPending': True}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
number_Dover = establishments.count_documents({'LocalAuthorityName': {'$regex' : 'Dover'}})

number_Dover
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})

# %%
# Check if any remaining documents include Dover
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('663d0ad74e28bb22b210c1a7'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({},  [ {'$set':{'geocode.longitude': {'$toDecimal': '$geocode.longitude'} }}])

establishments.update_many({}, [ {'$set':{'geocode.latitude': {'$toDecimal': '$geocode.latitude'} }}])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]

establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set': {'geocode.longitude':\
                                          {'$toDecimal': '$geocode.longitude'}}}])

establishments.update_many({}, [{'$set': {'geocode.latitude':\
                                          {'$toDecimal': '$geocode.latitude'}}}])

# %%
# Check that the coordinates and rating value are now numbers
test_change = establishments.find_one()
geocode_dict = test_change['geocode']

longitude_type = type(geocode_dict['longitude'])
print(longitude_type)

latitude_type = type(geocode_dict['latitude'])
print(latitude_type)
# Out:
# <class 'bson.decimal128.Decimal128'>
# <class 'bson.decimal128.Decimal128'>
